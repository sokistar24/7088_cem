# %%
import  gym
import time
from stable_baselines3 import DQN
from stable_baselines3 import PPO

# %%
env = gym.make("CartPole-v1")
print('State shape: ', env.observation_space.shape)
print('Number of actions: ', env.action_space.n)
# Out:
# State shape:  (4,)
# Number of actions:  2

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=20000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | 22.2     |
# | time/              |          |
# |    fps             | 1139     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.2         |
# |    ep_rew_mean          | 28.2         |
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0094461925 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.00155      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.42         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0173      |
# |    value_loss           | 51.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.1        |
# |    ep_rew_mean          | 36.1        |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010055981 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0996      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 38.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 46.1       |
# |    ep_rew_mean          | 46.1       |
# | time/                   |            |
# |    fps                  | 728        |
# |    iterations           | 4          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00729111 |
# |    clip_fraction        | 0.0866     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.628     |
# |    explained_variance   | 0.238      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0202    |
# |    value_loss           | 52.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.1         |
# |    ep_rew_mean          | 60.1         |
# | time/                   |              |
# |    fps                  | 679          |
# |    iterations           | 5            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0074553853 |
# |    clip_fraction        | 0.0615       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.243        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0155      |
# |    value_loss           | 64.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.4        |
# |    ep_rew_mean          | 75.4        |
# | time/                   |             |
# |    fps                  | 666         |
# |    iterations           | 6           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007884899 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.8        |
# |    ep_rew_mean          | 89.8        |
# | time/                   |             |
# |    fps                  | 668         |
# |    iterations           | 7           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010548898 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 47.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | 107         |
# | time/                   |             |
# |    fps                  | 656         |
# |    iterations           | 8           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008955738 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.708       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 48.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 123          |
# |    ep_rew_mean          | 123          |
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 9            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0035132307 |
# |    clip_fraction        | 0.0193       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.456        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00516     |
# |    value_loss           | 66.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 143         |
# | time/                   |             |
# |    fps                  | 641         |
# |    iterations           | 10          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012388156 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.565      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 29.6        |
# -----------------------------------------

# %%
import gymnasium as gym

# %%
env = gym.make("CartPole-v1",render_mode='human')

# %%
state,info = env.reset()
for j in range(30):
    action = action = env.action_space.sample() # take a random action
    env.render()
    time.sleep(0.5)
    state, reward,terminated,truncated,info= env.step(action)
    if terminated or truncated:
        break 
        
env.close()
